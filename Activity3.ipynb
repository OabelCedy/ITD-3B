# %% [markdown]
# <h1>UK ROAD ACCIDENTS DATA ANALYSIS</h1>
# <H2>INCLUSIVE YEAR 2019 - 2022</H2>
# <H2>Analyst : Cedrick S. Oabel</H2>
# <h2>DATA PREPARATION</h2>
# <h3>Transfer Data set to folder</h3>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway

# %% [markdown]
# <h1>DATA FRAMES</h1>

# %%
accident = pd.read_csv('datasets\\accident_data.csv')

# %%
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                          Daylight  Kensington and Chelsea  -0.173647
# 2       Darkness - lighting unknown  Kensington and Chelsea  -0.210215
# 3                          Daylight  Kensington and Chelsea  -0.202731
# 4             Darkness - lights lit  Kensington and Chelsea  -0.192487
# ...                             ...                     ...        ...
# 660674                     Daylight                Highland  -3.467828
# 660675       Darkness - no lighting                Highland  -3.809281
# 660676                     Daylight                Highland  -3.862727
# 660677       Darkness - no lighting                Highland  -3.823997
# 660678                     Daylight                Highland  -3.895673
#
#         Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                          1                   2                     Dry
# 1                          1                   2             Wet or damp
# 2                          1                   3                     Dry
# 3                          1                   4                     Dry
# 4                          1                   2                     Dry
# ...                      ...                 ...                     ...
# 660674                     2                   1                     Dry
# 660675                     1                   1            Frost or ice
# 660676                     1                   3            Frost or ice
# 660677                     1                   2             Wet or damp
# 660678                     1                   1             Wet or damp
#
#                  Road_Type Urban_or_Rural_Area     Weather_Conditions  \
# 0       Single carriageway               Urban     Fine no high winds
# 1       Single carriageway               Urban  Raining no high winds
# 2                      NaN               Urban                    NaN
# 3       Single carriageway               Urban     Fine no high winds
# 4                      NaN               Urban                    NaN
# ...                    ...                 ...                    ...
# 660674  Single carriageway               Rural     Fine no high winds
# 660675  Single carriageway               Rural     Fine no high winds
# 660676  Single carriageway               Rural     Fine no high winds
# 660677  Single carriageway               Rural     Fine no high winds
# 660678    Dual carriageway               Rural  Snowing no high winds
#
#                                 Vehicle_Type
# 0                                        Car
# 1                                        Car
# 2                      Taxi/Private hire car
# 3       Bus or coach (17 or more pass seats)
# 4                              Other vehicle
# ...                                      ...
# 660674                                   Car
# 660675                                   Car
# 660676                                   Car
# 660677                 Motorcycle over 500cc
# 660678                                   Car
#
# [660679 rows x 14 columns]

# %%
accident.dtypes
# Out:
# Index                       object
# Accident_Severity           object
# Accident Date               object
# Latitude                   float64
# Light_Conditions            object
# District Area               object
# Longitude                  float64
# Number_of_Casualties         int64
# Number_of_Vehicles           int64
# Road_Surface_Conditions     object
# Road_Type                   object
# Urban_or_Rural_Area         object
# Weather_Conditions          object
# Vehicle_Type                object
# dtype: object

# %%
accident.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %% [markdown]
# <h1>Categorical Data Fields</h1>

# %%
accident['Accident Date'] = accident['Accident Date'].astype('str')
accident['Light_Conditions'] = accident['Light_Conditions'].astype('category')
accident['Accident_Severity'] = accident['Accident_Severity'].astype('category')
accident['District Area'] = accident['District Area'].astype('category')
accident['Road_Surface_Conditions'] = accident['Road_Surface_Conditions'].astype('category')
accident['Urban_or_Rural_Area'] = accident['Urban_or_Rural_Area'].astype('category')
accident['Road_Type'] = accident['Road_Type'].astype('category')
accident['Weather_Conditions'] = accident['Weather_Conditions'].astype('category')
accident['Vehicle_Type'] = accident['Vehicle_Type'].astype('category')
accident['Latitude'] = accident['Latitude'].astype('category')
accident['Longitude'] = accident['Longitude'].astype('category')

# %% [markdown]
# <h1>Converting Data Field into DATE TIME data type</h1>

# %%
accident.dtypes
# Out:
# Index                        object
# Accident_Severity          category
# Accident Date                object
# Latitude                   category
# Light_Conditions           category
# District Area              category
# Longitude                  category
# Number_of_Casualties          int64
# Number_of_Vehicles            int64
# Road_Surface_Conditions    category
# Road_Type                  category
# Urban_or_Rural_Area        category
# Weather_Conditions         category
# Vehicle_Type               category
# dtype: object

# %%
accident['Accident Date'] = accident['Accident Date'].str.strip()
accident['Accident Date'] = accident['Accident Date'].str.replace('/','-')

# %%
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5-6-2019  51.506187
# 1       200701BS65737           Serious      2-7-2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3-9-2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea -0.209082
# 1                          Daylight  Kensington and Chelsea -0.173647
# 2       Darkness - lighting unknown  Kensington and Chelsea -0.210215
# 3                          Daylight  Kensington and Chelsea -0.202731
# 4             Darkness - lights lit  Kensington and Chelsea -0.192487
# ...                             ...                     ...       ...
# 660674                     Daylight                Highland -3.467828
# 660675       Darkness - no lighting                Highland -3.809281
# 660676                     Daylight                Highland -3.862727
# 660677       Darkness - no lighting                Highland -3.823997
# 660678                     Daylight                Highland -3.895673
#
#         Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                          1                   2                     Dry
# 1                          1                   2             Wet or damp
# 2                          1                   3                     Dry
# 3                          1                   4                     Dry
# 4                          1                   2                     Dry
# ...                      ...                 ...                     ...
# 660674                     2                   1                     Dry
# 660675                     1                   1            Frost or ice
# 660676                     1                   3            Frost or ice
# 660677                     1                   2             Wet or damp
# 660678                     1                   1             Wet or damp
#
#                  Road_Type Urban_or_Rural_Area     Weather_Conditions  \
# 0       Single carriageway               Urban     Fine no high winds
# 1       Single carriageway               Urban  Raining no high winds
# 2                      NaN               Urban                    NaN
# 3       Single carriageway               Urban     Fine no high winds
# 4                      NaN               Urban                    NaN
# ...                    ...                 ...                    ...
# 660674  Single carriageway               Rural     Fine no high winds
# 660675  Single carriageway               Rural     Fine no high winds
# 660676  Single carriageway               Rural     Fine no high winds
# 660677  Single carriageway               Rural     Fine no high winds
# 660678    Dual carriageway               Rural  Snowing no high winds
#
#                                 Vehicle_Type
# 0                                        Car
# 1                                        Car
# 2                      Taxi/Private hire car
# 3       Bus or coach (17 or more pass seats)
# 4                              Other vehicle
# ...                                      ...
# 660674                                   Car
# 660675                                   Car
# 660676                                   Car
# 660677                 Motorcycle over 500cc
# 660678                                   Car
#
# [660679 rows x 14 columns]

# %%
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'], dayfirst = True, errors = 'coerce')

# %%
accident.dtypes
# Out:
# Index                              object
# Accident_Severity                category
# Accident Date              datetime64[ns]
# Latitude                         category
# Light_Conditions                 category
# District Area                    category
# Longitude                        category
# Number_of_Casualties                int64
# Number_of_Vehicles                  int64
# Road_Surface_Conditions          category
# Road_Type                        category
# Urban_or_Rural_Area              category
# Weather_Conditions               category
# Vehicle_Type                     category
# dtype: object

# %%
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'], dayfirst = True, errors = 'coerce')

# %%
accident['Accident Date']
# Out:
# 0        2019-06-05
# 1        2019-07-02
# 2        2019-08-26
# 3        2019-08-16
# 4        2019-09-03
#             ...
# 660674   2022-02-18
# 660675   2022-02-21
# 660676   2022-02-23
# 660677   2022-02-23
# 660678   2022-02-28
# Name: Accident Date, Length: 660679, dtype: datetime64[ns]

# %% [markdown]
# <H1>Data Cleansing</H1>

# %%
accident['Road_Surface_Conditions'] = accident['Road_Surface_Conditions'].astype('str')
accident['Latitude'] = accident['Latitude'].fillna(accident['Latitude'].mode()[0])
accident['Accident Date'] = accident['Accident Date'].fillna('Unknown Date')
accident['Longitude'] = accident['Longitude'].fillna(accident['Longitude'].mode()[0])
accident['Road_Surface_Conditions'] = accident['Road_Surface_Conditions'].fillna('unknown road condition')
accident['Urban_or_Rural_Area'] = accident['Urban_or_Rural_Area'].fillna(accident['Urban_or_Rural_Area'].mode()[0])
accident['Road_Type'] = accident['Road_Type'].fillna(accident['Road_Type'].mode()[0])
accident['Weather_Conditions'] = accident['Weather_Conditions'].fillna(accident['Weather_Conditions'].mode()[0])

# %%
accident.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# dtype: int64

# %%
accident['Accident Date']
# Out:
# 0        2019-06-05
# 1        2019-07-02
# 2        2019-08-26
# 3        2019-08-16
# 4        2019-09-03
#             ...
# 660674   2022-02-18
# 660675   2022-02-21
# 660676   2022-02-23
# 660677   2022-02-23
# 660678   2022-02-28
# Name: Accident Date, Length: 660679, dtype: datetime64[ns]

# %%
accident['Weather_Conditions'].value_counts()
# Out:
# Weather_Conditions
# Fine no high winds       535013
# Raining no high winds     79696
# Other                     17150
# Raining + high winds       9615
# Fine + high winds          8554
# Snowing no high winds      6238
# Fog or mist                3528
# Snowing + high winds        885
# Name: count, dtype: int64

# %% [markdown]
# <h1>Univariate Analysis on accidentthat happened in 2019</h1>

# %%
accident['Light_Conditions'].value_counts().sum()
# Out:
# np.int64(660679)

# %%
accident['Day'] = accident['Accident Date'].dt.day_name()

# %%
accident['Day'].value_counts()
# Out:
# Day
# Saturday     107178
# Wednesday     99558
# Thursday      99511
# Friday        97900
# Tuesday       94550
# Sunday        89302
# Monday        72680
# Name: count, dtype: int64

# %%
Aci = accident.groupby(['Weather_Conditions','Accident Date']).size()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\925390540.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Aci = accident.groupby(['Weather_Conditions','Accident Date']).size()

# %%
Aci
# Out:
# Weather_Conditions     Accident Date
# Fine + high winds      2019-01-01       33
#                        2019-01-02       16
#                        2019-01-03       32
#                        2019-01-04       27
#                        2019-01-05        4
#                                         ..
# Snowing no high winds  2022-12-27       12
#                        2022-12-28        1
#                        2022-12-29        0
#                        2022-12-30        0
#                        2022-12-31        1
# Length: 11688, dtype: int64

# %% [markdown]
# <h1>Insight No.1: Accident Occured on 2019 during the Fine + high winds Weather_Conditions is dated 2019-01-01 with 33 Accident</h1>

# %% [markdown]
# <h1>Casualties for Road Weather or Weather Conditions in Road types and The Number of Casualties</h1>

# %%
road_weather = accident.groupby(['Weather_Conditions','Road_Type','Number_of_Casualties']).size()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\1918757322.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   road_weather = accident.groupby(['Weather_Conditions','Road_Type','Number_of_Casualties']).size()

# %%
road_weather.unstack()
# Out:
# Number_of_Casualties                          1      2      3     4     5   \
# Weather_Conditions    Road_Type
# Fine + high winds     Dual carriageway      1083    298     82    35    10
#                       One way street         133     21      4     0     0
#                       Roundabout             417     85     24    12     1
#                       Single carriageway    4634   1084    334   121    32
#                       Slip road               81     19      7     2     0
# Fine no high winds    Dual carriageway     55234  15439   4819  1867   736
#                       One way street        9857   1175    242    75    26
#                       Roundabout           28886   5178   1263   366   137
#                       Single carriageway  313350  62491  17496  6368  2287
#                       Slip road             4106   1084    306   101    41
# Fog or mist           Dual carriageway       437    157     58    12     7
#                       One way street          23      5      1     0     0
#                       Roundabout             175     31      9     6     1
#                       Single carriageway    1878    450    141    68    13
#                       Slip road               26      5      0     1     0
# Other                 Dual carriageway      1626    439    121    44    20
#                       One way street         252     44     11     2     0
#                       Roundabout             880    177     37    13     1
#                       Single carriageway   10111   2236    614   218    75
#                       Slip road              130     34     10     2     3
# Raining + high winds  Dual carriageway      1408    420    133    39    18
#                       One way street         124     20      5     2     1
#                       Roundabout             457     80     20     2     3
#                       Single carriageway    4952   1211    358   143    55
#                       Slip road               76     22      6     1     1
# Raining no high winds Dual carriageway      8949   2703    836   326   142
#                       One way street        1188    176     39    14    10
#                       Roundabout            4236    807    189    88    21
#                       Single carriageway   43340  10663   3218  1105   443
#                       Slip road              621    168     53    15     5
# Snowing + high winds  Dual carriageway       136     38      4     4     1
#                       One way street          13      1      0     0     0
#                       Roundabout              19      8      2     0     1
#                       Single carriageway     470    109     47    12     4
#                       Slip road                8      1      1     0     0
# Snowing no high winds Dual carriageway       746    191     49    23     7
#                       One way street          66      9      1     1     1
#                       Roundabout             221     53     11     4     0
#                       Single carriageway    3636    829    222    64    20
#                       Slip road               56     10      3     0     0
#
# Number_of_Casualties                       6    7    8   9   10  ...  29  32  \
# Weather_Conditions    Road_Type                                  ...
# Fine + high winds     Dual carriageway      7    2    1   0   0  ...   0   0
#                       One way street        0    0    0   0   0  ...   0   0
#                       Roundabout            0    0    1   0   0  ...   0   0
#                       Single carriageway   16    4    0   1   1  ...   0   0
#                       Slip road             0    0    0   0   0  ...   0   0
# Fine no high winds    Dual carriageway    310  132   56  29  22  ...   0   1
#                       One way street        4    4    0   2   1  ...   0   0
#                       Roundabout           39    9    4   2   2  ...   0   0
#                       Single carriageway  839  287  112  56  20  ...   3   0
#                       Slip road            14    7    2   1   2  ...   0   0
# Fog or mist           Dual carriageway      5    1    1   0   0  ...   0   0
#                       One way street        0    0    0   0   0  ...   0   0
#                       Roundabout            0    0    0   0   0  ...   0   0
#                       Single carriageway    7    5    0   0   0  ...   0   0
#                       Slip road             1    0    0   0   0  ...   0   0
# Other                 Dual carriageway      9    2    1   1   0  ...   0   0
#                       One way street        0    0    0   0   0  ...   0   0
#                       Roundabout            1    0    0   0   0  ...   0   0
#                       Single carriageway   22    6    2   1   2  ...   0   0
#                       Slip road             0    0    0   0   0  ...   0   0
# Raining + high winds  Dual carriageway      8    3    1   2   0  ...   0   0
#                       One way street        0    0    1   0   0  ...   0   0
#                       Roundabout            1    0    0   0   0  ...   0   0
#                       Single carriageway   24    8    6   1   1  ...   0   0
#                       Slip road             1    0    0   0   0  ...   0   0
# Raining no high winds Dual carriageway     44   18    7   4   2  ...   0   0
#                       One way street        2    0    0   0   0  ...   0   0
#                       Roundabout            5    1    0   0   0  ...   0   0
#                       Single carriageway  151   43   18  12   5  ...   0   0
#                       Slip road             1    1    0   0   0  ...   0   0
# Snowing + high winds  Dual carriageway      2    0    0   0   0  ...   0   0
#                       One way street        0    0    0   0   0  ...   0   0
#                       Roundabout            0    0    0   0   0  ...   0   0
#                       Single carriageway    2    1    1   0   0  ...   0   0
#                       Slip road             0    0    0   0   0  ...   0   0
# Snowing no high winds Dual carriageway      3    1    0   0   0  ...   0   0
#                       One way street        0    0    0   0   0  ...   0   0
#                       Roundabout            1    0    0   0   0  ...   0   0
#                       Single carriageway    6    4    0   0   0  ...   0   0
#                       Slip road             0    0    0   0   0  ...   0   0
#
# Number_of_Casualties                      40  42  43  45  47  48  62  68
# Weather_Conditions    Road_Type
# Fine + high winds     Dual carriageway     0   0   0   0   0   0   0   0
#                       One way street       0   0   0   0   0   0   0   0
#                       Roundabout           0   0   0   0   0   0   0   0
#                       Single carriageway   0   0   0   0   0   0   0   0
#                       Slip road            0   0   0   0   0   0   0   0
# Fine no high winds    Dual carriageway     1   0   1   1   0   0   0   0
#                       One way street       0   0   0   0   0   0   0   0
#                       Roundabout           0   0   0   0   0   0   0   0
#                       Single carriageway   1   1   0   0   0   0   1   0
#                       Slip road            0   0   0   0   0   0   0   0
# Fog or mist           Dual carriageway     0   1   0   0   0   0   0   0
#                       One way street       0   0   0   0   0   0   0   0
#                       Roundabout           0   0   0   0   0   0   0   0
#                       Single carriageway   0   0   0   0   0   0   0   0
#                       Slip road            0   0   0   0   0   0   0   0
# Other                 Dual carriageway     0   0   0   0   0   0   0   0
#                       One way street       0   0   0   0   0   0   0   0
#                       Roundabout           0   0   0   0   0   0   0   0
#                       Single carriageway   0   0   0   0   0   1   0   0
#                       Slip road            0   0   0   0   0   0   0   0
# Raining + high winds  Dual carriageway     0   0   0   0   0   0   0   0
#                       One way street       0   0   0   0   0   0   0   0
#                       Roundabout           0   0   0   0   0   0   0   0
#                       Single carriageway   0   0   0   0   0   0   0   0
#                       Slip road            0   0   0   0   0   0   0   0
# Raining no high winds Dual carriageway     0   0   0   0   1   0   0   0
#                       One way street       0   0   0   0   0   0   0   0
#                       Roundabout           0   0   0   0   0   0   0   0
#                       Single carriageway   0   0   0   0   0   0   0   0
#                       Slip road            0   0   0   0   0   0   0   1
# Snowing + high winds  Dual carriageway     0   0   0   0   0   0   0   0
#                       One way street       0   0   0   0   0   0   0   0
#                       Roundabout           0   0   0   0   0   0   0   0
#                       Single carriageway   0   0   0   0   0   0   0   0
#                       Slip road            0   0   0   0   0   0   0   0
# Snowing no high winds Dual carriageway     0   0   0   0   0   0   0   0
#                       One way street       0   0   0   0   0   0   0   0
#                       Roundabout           0   0   0   0   0   0   0   0
#                       Single carriageway   0   0   0   0   0   0   0   0
#                       Slip road            0   0   0   0   0   0   0   0
#
# [40 rows x 36 columns]

# %%
accident['Number_of_Casualties'].count()
# Out:
# np.int64(660679)

# %% [markdown]
# <h1>Insight No. 2: Road Weather Accident occured in 'Fine no high winds' indicates that there is 47.42% casualties in a Single carriageway</h1>

# %%
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    2019-06-05  51.506187
# 1       200701BS65737           Serious    2019-07-02  51.495029
# 2       200701BS66127           Serious    2019-08-26  51.517715
# 3       200701BS66128           Serious    2019-08-16  51.495478
# 4       200701BS66837            Slight    2019-09-03  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    2022-02-18  57.374005
# 660675  201091NM01881            Slight    2022-02-21  57.232273
# 660676  201091NM01935            Slight    2022-02-23  57.585044
# 660677  201091NM01964           Serious    2022-02-23  57.214898
# 660678  201091NM02142           Serious    2022-02-28  57.575210
#
#                    Light_Conditions           District Area Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea -0.209082
# 1                          Daylight  Kensington and Chelsea -0.173647
# 2       Darkness - lighting unknown  Kensington and Chelsea -0.210215
# 3                          Daylight  Kensington and Chelsea -0.202731
# 4             Darkness - lights lit  Kensington and Chelsea -0.192487
# ...                             ...                     ...       ...
# 660674                     Daylight                Highland -3.467828
# 660675       Darkness - no lighting                Highland -3.809281
# 660676                     Daylight                Highland -3.862727
# 660677       Darkness - no lighting                Highland -3.823997
# 660678                     Daylight                Highland -3.895673
#
#         Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                          1                   2                     Dry
# 1                          1                   2             Wet or damp
# 2                          1                   3                     Dry
# 3                          1                   4                     Dry
# 4                          1                   2                     Dry
# ...                      ...                 ...                     ...
# 660674                     2                   1                     Dry
# 660675                     1                   1            Frost or ice
# 660676                     1                   3            Frost or ice
# 660677                     1                   2             Wet or damp
# 660678                     1                   1             Wet or damp
#
#                  Road_Type Urban_or_Rural_Area     Weather_Conditions  \
# 0       Single carriageway               Urban     Fine no high winds
# 1       Single carriageway               Urban  Raining no high winds
# 2       Single carriageway               Urban     Fine no high winds
# 3       Single carriageway               Urban     Fine no high winds
# 4       Single carriageway               Urban     Fine no high winds
# ...                    ...                 ...                    ...
# 660674  Single carriageway               Rural     Fine no high winds
# 660675  Single carriageway               Rural     Fine no high winds
# 660676  Single carriageway               Rural     Fine no high winds
# 660677  Single carriageway               Rural     Fine no high winds
# 660678    Dual carriageway               Rural  Snowing no high winds
#
#                                 Vehicle_Type        Day
# 0                                        Car  Wednesday
# 1                                        Car    Tuesday
# 2                      Taxi/Private hire car     Monday
# 3       Bus or coach (17 or more pass seats)     Friday
# 4                              Other vehicle    Tuesday
# ...                                      ...        ...
# 660674                                   Car     Friday
# 660675                                   Car     Monday
# 660676                                   Car  Wednesday
# 660677                 Motorcycle over 500cc  Wednesday
# 660678                                   Car     Monday
#
# [660679 rows x 15 columns]

# %%
sever = accident.groupby(['Accident_Severity','Accident Date','Vehicle_Type']).size()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\1187953922.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sever = accident.groupby(['Accident_Severity','Accident Date','Vehicle_Type']).size()

# %%
sever
# Out:
# Accident_Severity  Accident Date  Vehicle_Type
# Fatal              2019-01-01     Agricultural vehicle                     0
#                                   Bus or coach (17 or more pass seats)     0
#                                   Car                                      9
#                                   Data missing or out of range             0
#                                   Goods 7.5 tonnes mgw and over            0
#                                                                           ..
# Slight             2022-12-31     Other vehicle                            0
#                                   Pedal cycle                              0
#                                   Ridden horse                             0
#                                   Taxi/Private hire car                    4
#                                   Van / Goods 3.5 tonnes mgw or under     10
# Length: 70128, dtype: int64

# %%
sever.unstack()
# Out:
# Vehicle_Type                     Agricultural vehicle  \
# Accident_Severity Accident Date
# Fatal             2019-01-01                        0
#                   2019-01-02                        0
#                   2019-01-03                        0
#                   2019-01-04                        0
#                   2019-01-05                        0
# ...                                               ...
# Slight            2022-12-27                        0
#                   2022-12-28                        0
#                   2022-12-29                        1
#                   2022-12-30                        1
#                   2022-12-31                        0
#
# Vehicle_Type                     Bus or coach (17 or more pass seats)  Car  \
# Accident_Severity Accident Date
# Fatal             2019-01-01                                        0    9
#                   2019-01-02                                        0    4
#                   2019-01-03                                        0    5
#                   2019-01-04                                        0    4
#                   2019-01-05                                        0    5
# ...                                                               ...  ...
# Slight            2022-12-27                                        4  128
#                   2022-12-28                                        1  114
#                   2022-12-29                                       10  136
#                   2022-12-30                                        6  119
#                   2022-12-31                                        4  126
#
# Vehicle_Type                     Data missing or out of range  \
# Accident_Severity Accident Date
# Fatal             2019-01-01                                0
#                   2019-01-02                                0
#                   2019-01-03                                0
#                   2019-01-04                                0
#                   2019-01-05                                0
# ...                                                       ...
# Slight            2022-12-27                                0
#                   2022-12-28                                0
#                   2022-12-29                                0
#                   2022-12-30                                0
#                   2022-12-31                                0
#
# Vehicle_Type                     Goods 7.5 tonnes mgw and over  \
# Accident_Severity Accident Date
# Fatal             2019-01-01                                 0
#                   2019-01-02                                 0
#                   2019-01-03                                 0
#                   2019-01-04                                 1
#                   2019-01-05                                 1
# ...                                                        ...
# Slight            2022-12-27                                 1
#                   2022-12-28                                 4
#                   2022-12-29                                 8
#                   2022-12-30                                 2
#                   2022-12-31                                 3
#
# Vehicle_Type                     Goods over 3.5t. and under 7.5t  \
# Accident_Severity Accident Date
# Fatal             2019-01-01                                   0
#                   2019-01-02                                   0
#                   2019-01-03                                   0
#                   2019-01-04                                   0
#                   2019-01-05                                   0
# ...                                                          ...
# Slight            2022-12-27                                   0
#                   2022-12-28                                   0
#                   2022-12-29                                   1
#                   2022-12-30                                   1
#                   2022-12-31                                   1
#
# Vehicle_Type                     Minibus (8 - 16 passenger seats)  \
# Accident_Severity Accident Date
# Fatal             2019-01-01                                    0
#                   2019-01-02                                    0
#                   2019-01-03                                    0
#                   2019-01-04                                    0
#                   2019-01-05                                    0
# ...                                                           ...
# Slight            2022-12-27                                    2
#                   2022-12-28                                    2
#                   2022-12-29                                    0
#                   2022-12-30                                    0
#                   2022-12-31                                    0
#
# Vehicle_Type                     Motorcycle 125cc and under  \
# Accident_Severity Accident Date
# Fatal             2019-01-01                              0
#                   2019-01-02                              0
#                   2019-01-03                              1
#                   2019-01-04                              0
#                   2019-01-05                              0
# ...                                                     ...
# Slight            2022-12-27                              4
#                   2022-12-28                              2
#                   2022-12-29                              4
#                   2022-12-30                              5
#                   2022-12-31                              6
#
# Vehicle_Type                     Motorcycle 50cc and under  \
# Accident_Severity Accident Date
# Fatal             2019-01-01                             0
#                   2019-01-02                             0
#                   2019-01-03                             1
#                   2019-01-04                             0
#                   2019-01-05                             0
# ...                                                    ...
# Slight            2022-12-27                             0
#                   2022-12-28                             2
#                   2022-12-29                             1
#                   2022-12-30                             3
#                   2022-12-31                             0
#
# Vehicle_Type                     Motorcycle over 125cc and up to 500cc  \
# Accident_Severity Accident Date
# Fatal             2019-01-01                                         1
#                   2019-01-02                                         0
#                   2019-01-03                                         0
#                   2019-01-04                                         0
#                   2019-01-05                                         0
# ...                                                                ...
# Slight            2022-12-27                                         0
#                   2022-12-28                                         1
#                   2022-12-29                                         4
#                   2022-12-30                                         1
#                   2022-12-31                                         2
#
# Vehicle_Type                     Motorcycle over 500cc  Other vehicle  \
# Accident_Severity Accident Date
# Fatal             2019-01-01                         0              0
#                   2019-01-02                         0              0
#                   2019-01-03                         0              0
#                   2019-01-04                         0              0
#                   2019-01-05                         0              0
# ...                                                ...            ...
# Slight            2022-12-27                         6              1
#                   2022-12-28                         4              2
#                   2022-12-29                         7              1
#                   2022-12-30                         1              2
#                   2022-12-31                         9              0
#
# Vehicle_Type                     Pedal cycle  Ridden horse  \
# Accident_Severity Accident Date
# Fatal             2019-01-01               0             0
#                   2019-01-02               0             0
#                   2019-01-03               0             0
#                   2019-01-04               0             0
#                   2019-01-05               0             0
# ...                                      ...           ...
# Slight            2022-12-27               0             0
#                   2022-12-28               0             0
#                   2022-12-29               0             0
#                   2022-12-30               0             0
#                   2022-12-31               0             0
#
# Vehicle_Type                     Taxi/Private hire car  \
# Accident_Severity Accident Date
# Fatal             2019-01-01                         0
#                   2019-01-02                         1
#                   2019-01-03                         0
#                   2019-01-04                         0
#                   2019-01-05                         0
# ...                                                ...
# Slight            2022-12-27                         4
#                   2022-12-28                         4
#                   2022-12-29                         6
#                   2022-12-30                         3
#                   2022-12-31                         4
#
# Vehicle_Type                     Van / Goods 3.5 tonnes mgw or under
# Accident_Severity Accident Date
# Fatal             2019-01-01                                       1
#                   2019-01-02                                       1
#                   2019-01-03                                       0
#                   2019-01-04                                       1
#                   2019-01-05                                       1
# ...                                                              ...
# Slight            2022-12-27                                       8
#                   2022-12-28                                      12
#                   2022-12-29                                       9
#                   2022-12-30                                       6
#                   2022-12-31                                      10
#
# [4383 rows x 16 columns]

# %% [markdown]
# <h1>Insight No. 3: There is a total of 9 fatal Car Accident that has happend or occured on the date 2019-01-01  </h1>

# %%
Area = accident.groupby(['District Area','Number_of_Casualties','Vehicle_Type']).size()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\3935612014.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Area = accident.groupby(['District Area','Number_of_Casualties','Vehicle_Type']).size()

# %%
Area
# Out:
# District Area  Number_of_Casualties  Vehicle_Type
# Aberdeen City  1                     Agricultural vehicle                      2
#                                      Bus or coach (17 or more pass seats)     81
#                                      Car                                     844
#                                      Data missing or out of range              0
#                                      Goods 7.5 tonnes mgw and over            32
#                                                                             ...
# York           68                    Other vehicle                             0
#                                      Pedal cycle                               0
#                                      Ridden horse                              0
#                                      Taxi/Private hire car                     0
#                                      Van / Goods 3.5 tonnes mgw or under       0
# Length: 243072, dtype: int64

# %%
light_vehicles = accident.groupby(['Light_Conditions', 'Number_of_Vehicles']).size()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\3287015029.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   light_vehicles = accident.groupby(['Light_Conditions', 'Number_of_Vehicles']).size()

# %% [markdown]
# <h1>Insight No.4 How many Vehicles accident occured in Light Conditions</h1>

# %%
road_vehicles = accident.groupby('Road_Type')['Number_of_Vehicles'].mean()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\830570568.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   road_vehicles = accident.groupby('Road_Type')['Number_of_Vehicles'].mean()

# %% [markdown]
# <h1>Insight No.5: Number of Accidents that has happened in the Types of Road</h1>

# %%
weather_casualties = accident.groupby('Weather_Conditions')['Number_of_Casualties'].mean()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\1264165256.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weather_casualties = accident.groupby('Weather_Conditions')['Number_of_Casualties'].mean()

# %% [markdown]
# <h1>Insight No.6: Average casualties that caused by the Weather Condition</h1>

# %%
weather_severity = accident.groupby(['Weather_Conditions', 'Accident_Severity']).size().unstack()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\3803141711.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weather_severity = accident.groupby(['Weather_Conditions', 'Accident_Severity']).size().unstack()

# %% [markdown]
# <h1>Insight No.7: Correlation Between Weather Condition and Accident Severity</h1>

# %%
vehicle_casualties = accident.groupby('Vehicle_Type')['Number_of_Casualties'].mean()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\418938031.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   vehicle_casualties = accident.groupby('Vehicle_Type')['Number_of_Casualties'].mean()#Average casualties by vehicle type

# %% [markdown]
# <h1>Insight No.8: The Casualties caused of many Vehicle Types</h1>

# %%
surface_casualties = accident.groupby('Road_Surface_Conditions')['Number_of_Casualties'].mean()

# %% [markdown]
# <h1>Insight No9: Casualties in the Road Surface Condition</h1>

# %%
weather_vehicles = accident.groupby('Weather_Conditions')['Number_of_Vehicles'].mean()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\268265449.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weather_vehicles = accident.groupby('Weather_Conditions')['Number_of_Vehicles'].mean()

# %% [markdown]
# <h1>Insight No.9 The Impact and involvement of weather in vehicle</h1>

# %%
severity_time = accident.groupby([accident['Accident Date'].dt.year, 'Accident_Severity']).size().unstack()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\281628468.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   severity_time = accident.groupby([accident['Accident Date'].dt.year, 'Accident_Severity']).size().unstack()#Severity distribution over time

# %% [markdown]
# <h1>Insight No. 10:Overtime Severity of accidents </h1>

# %%
severity_area = accident.groupby(['Accident_Severity', 'Urban_or_Rural_Area']).size()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\3523771247.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   severity_area = accident.groupby(['Accident_Severity', 'Urban_or_Rural_Area']).size()

# %% [markdown]
# <h1>Insights No.11: Accidents in Urban/Rural Area and how severe was it</h1>

# %%
area_vehicles = accident.groupby('Urban_or_Rural_Area')['Number_of_Vehicles'].mean()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\1233159333.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   area_vehicles = accident.groupby('Urban_or_Rural_Area')['Number_of_Vehicles'].mean()

# %% [markdown]
# <h1>Insight No. 12: Impact of Rural and Urban and of how many vehicle accidents occur in rural and urban </h1>

# %%
light_severity = accident.groupby('Light_Conditions')['Accident_Severity'].value_counts().unstack()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\2553006003.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   light_severity = accident.groupby('Light_Conditions')['Accident_Severity'].value_counts().unstack()

# %% [markdown]
# <h1>Insight No.13: How Severe is Light Conditions and How many accidents Occured in Light conditions </h1>

# %%
road_vehicle_count = accident.groupby('Road_Type')['Number_of_Vehicles'].mean()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\4219825393.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   road_vehicle_count = accident.groupby('Road_Type')['Number_of_Vehicles'].mean()

# %% [markdown]
# <h1>Insight No.14: The Involvement of types of Road that vehicles travel to and it's impact </h1>

# %%
weather_light_vehicles = accident.groupby(['Weather_Conditions', 'Light_Conditions'])['Number_of_Vehicles'].mean()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\403702901.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weather_light_vehicles = accident.groupby(['Weather_Conditions', 'Light_Conditions'])['Number_of_Vehicles'].mean()

# %% [markdown]
# <h1>Insight No.15:Vehicle count based on weather and light conditions </h1>

# %%
area_vehicles = accident.groupby('Urban_or_Rural_Area')['Number_of_Vehicles'].mean()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\1233159333.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   area_vehicles = accident.groupby('Urban_or_Rural_Area')['Number_of_Vehicles'].mean()

# %% [markdown]
# <h1>Insight No.16: Impact of urban vs rural areas on vehicle count adding more and more casualties and accidents </h1>

# %%
casualty_severity = accident.groupby('Road_Type')['Number_of_Casualties'].value_counts().unstack()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\4226927514.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   casualty_severity = accident.groupby('Road_Type')['Number_of_Casualties'].value_counts().unstack()

# %% [markdown]
# <h1>Insight No. 17: Severity on each Road Types that's adding more accidents</h1>

# %%
surface_casualties = accident.groupby('Road_Surface_Conditions')['Number_of_Casualties'].mean()

# %% [markdown]
# <h1>Insight No.18: Surface Casualties</h1>

# %%
road_weather = accident.groupby(['Weather_Conditions','Road_Type','Number_of_Casualties']).size()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_14412\1918757322.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   road_weather = accident.groupby(['Weather_Conditions','Road_Type','Number_of_Casualties']).size()

# %% [markdown]
# <h1>Insight No.19: Road Weather affecting road types and increasing Casualties</h1>

# %%
months = accident['Day'].value_counts().sort_index()

# %% [markdown]
# <h1>Insight No.20: Day Results of Accidents in the Year 2019-2022 </h1>
